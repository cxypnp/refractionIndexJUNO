# %% [markdown]
# Python Symbolic Calculation

# %%
from sympy import *
from sympy.simplify.fu import *
init_printing()

A, P, r= symbols('A P r',real=true)
p, s = symbols('R_p R_s',real=1)

initVector=Matrix([1,r])
rotationP=Matrix([[cos(P),sin(P)],[-sin(P),cos(P)]])
reflection=Matrix([[p,0],[0,s]])
rotationA=Matrix([[cos(A),-sin(A)],[sin(A),cos(A)]])
polarizor=Matrix([[1,0],[0,r]])

finalVector=polarizor*rotationA*reflection*rotationP*initVector

finalVectorConjugate=(polarizor*rotationA*reflection.conjugate()*rotationP*initVector).T

intensity=(finalVectorConjugate*finalVector)[0,0].expand()
result=collect(TR7(TR5(TR7(trigsimp(intensity,method="combined")))).expand(),[cos(2*A),sin(2*A),cos(2*P),sin(2*P),r]).subs(sin(P)*cos(P),Rational(1, 2)*sin(2*P))

# %%
result
# Out:
#   2     2      ⎛  2     2⎞      ⎛  2              2         ⎞      ⎛  2     2⎞
# Rₚ    Rₛ     4 ⎜Rₚ    Rₛ ⎟    3 ⎜Rₚ ⋅sin(2⋅P)   Rₛ ⋅sin(2⋅P)⎟    2 ⎜Rₚ    Rₛ ⎟
# ─── + ─── + r ⋅⎜─── + ───⎟ + r ⋅⎜──────────── - ────────────⎟ + r ⋅⎜─── + ───⎟
#  4     4       ⎝ 4     4 ⎠      ⎝     2              2      ⎠      ⎝ 2     2 ⎠
#
#      ⎛  2              2         ⎞   ⎛    2  4     2     2  4     2⎞
#      ⎜Rₚ ⋅sin(2⋅P)   Rₛ ⋅sin(2⋅P)⎟   ⎜  Rₚ ⋅r    Rₚ    Rₛ ⋅r    Rₛ ⎟
#  + r⋅⎜──────────── - ────────────⎟ + ⎜- ────── + ─── + ────── - ───⎟⋅cos(2⋅P)
#      ⎝     2              2      ⎠   ⎝    4       4      4       4 ⎠
#
#   ⎛       4
#   ⎜Rₚ⋅Rₛ⋅r ⋅sin(2⋅P)          3                   2
# + ⎜───────────────── + Rₚ⋅Rₛ⋅r ⋅cos(2⋅P) - Rₚ⋅Rₛ⋅r ⋅sin(2⋅P) - Rₚ⋅Rₛ⋅r⋅cos(2⋅P
#   ⎝        2
#
#                   ⎞            ⎛  2  4              2  4     2  3
#     Rₚ⋅Rₛ⋅sin(2⋅P)⎟            ⎜Rₚ ⋅r ⋅cos(2⋅P)   Rₚ ⋅r    Rₚ ⋅r ⋅sin(2⋅P)   R
# ) + ──────────────⎟⋅sin(2⋅A) + ⎜─────────────── - ────── - ─────────────── - ─
#           2       ⎠            ⎝       4            4             2
#
#  2  2              2                2              2     2  4              2
# ₚ ⋅r ⋅cos(2⋅P)   Rₚ ⋅r⋅sin(2⋅P)   Rₚ ⋅cos(2⋅P)   Rₚ    Rₛ ⋅r ⋅cos(2⋅P)   Rₛ ⋅r
# ────────────── + ────────────── + ──────────── + ─── + ─────────────── + ─────
#       2                2               4          4           4            4
#
# 4     2  3              2  2              2                2              2⎞
#     Rₛ ⋅r ⋅sin(2⋅P)   Rₛ ⋅r ⋅cos(2⋅P)   Rₛ ⋅r⋅sin(2⋅P)   Rₛ ⋅cos(2⋅P)   Rₛ ⎟
# ─ - ─────────────── - ─────────────── + ────────────── + ──────────── - ───⎟⋅c
#            2                 2                2               4          4 ⎠
#
#
#
# os(2⋅A)

# %%
print(latex(result))
# Out:
# \frac{R_{p}^{2}}{4} + \frac{R_{s}^{2}}{4} + r^{4} \left(\frac{R_{p}^{2}}{4} + \frac{R_{s}^{2}}{4}\right) + r^{3} \left(\frac{R_{p}^{2} \sin{\left(2 P \right)}}{2} - \frac{R_{s}^{2} \sin{\left(2 P \right)}}{2}\right) + r^{2} \left(\frac{R_{p}^{2}}{2} + \frac{R_{s}^{2}}{2}\right) + r \left(\frac{R_{p}^{2} \sin{\left(2 P \right)}}{2} - \frac{R_{s}^{2} \sin{\left(2 P \right)}}{2}\right) + \left(- \frac{R_{p}^{2} r^{4}}{4} + \frac{R_{p}^{2}}{4} + \frac{R_{s}^{2} r^{4}}{4} - \frac{R_{s}^{2}}{4}\right) \cos{\left(2 P \right)} + \left(\frac{R_{p} R_{s} r^{4} \sin{\left(2 P \right)}}{2} + R_{p} R_{s} r^{3} \cos{\left(2 P \right)} - R_{p} R_{s} r^{2} \sin{\left(2 P \right)} - R_{p} R_{s} r \cos{\left(2 P \right)} + \frac{R_{p} R_{s} \sin{\left(2 P \right)}}{2}\right) \sin{\left(2 A \right)} + \left(\frac{R_{p}^{2} r^{4} \cos{\left(2 P \right)}}{4} - \frac{R_{p}^{2} r^{4}}{4} - \frac{R_{p}^{2} r^{3} \sin{\left(2 P \right)}}{2} - \frac{R_{p}^{2} r^{2} \cos{\left(2 P \right)}}{2} + \frac{R_{p}^{2} r \sin{\left(2 P \right)}}{2} + \frac{R_{p}^{2} \cos{\left(2 P \right)}}{4} + \frac{R_{p}^{2}}{4} + \frac{R_{s}^{2} r^{4} \cos{\left(2 P \right)}}{4} + \frac{R_{s}^{2} r^{4}}{4} - \frac{R_{s}^{2} r^{3} \sin{\left(2 P \right)}}{2} - \frac{R_{s}^{2} r^{2} \cos{\left(2 P \right)}}{2} + \frac{R_{s}^{2} r \sin{\left(2 P \right)}}{2} + \frac{R_{s}^{2} \cos{\left(2 P \right)}}{4} - \frac{R_{s}^{2}}{4}\right) \cos{\left(2 A \right)}

# %%
result.subs(P,0.01).subs(p,0.001).subs(s,1).subs(r,0.005)
# Out:
# 4.99995832791673e-6⋅sin(2⋅A) - 1.20001166538944e-5⋅cos(2⋅A) + 1.30007416738943
# e-5

# %%
result.subs(P,0.01).subs(p,0.001).subs(s,1).subs(r,0)
# Out:
# 9.99933334666654e-6⋅sin(2⋅A) - 4.94983833538943e-5⋅cos(2⋅A) + 5.04982833572276
# e-5
